# %% [markdown]
# # Neural Network
#
# Xây dựng neural network với hai tầng ẩn (hidden layer).
# Các trọng số và mối liên hệ giữa các tầng ẩn được thiết lập
# và cài đặt bằng tay.

# %% [markdown]
# ## Neural Network Overview
#
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" alt="nn" style="width: 400px;"/>
#
# ## MNIST Dataset Overview
#
# MNIST là bộ dữ liệu chứa các ảnh là các ký tự viết tay, chia thành 2 phần, 60000 ảnh dùng để huấn luyện và 10000 ảnh dùng để kiểm thử. Kích thước các ảnh là 28x28, giá trị các pixel thuộc [0,255]
#
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)
#
# More info: http://yann.lecun.com/exdb/mnist/

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# MNIST dataset parameters.
num_classes = 10 # total classes (0-9 digits).
num_features = 784 # data features (img shape: 28*28).

# Network parameters.
n_hidden_1 = 128 # 1st layer number of neurons.
# n_hidden_2 = 256 # 2nd layer number of neurons.

# %%
pip install tensorflow-cpu
# Out:
# Collecting tensorflow-cpu
#   Downloading tensorflow_cpu-2.21.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-cpu)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-cpu)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow-cpu)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-cpu)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow-cpu)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-cpu)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow-cpu)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\hungn\miniconda3\lib\site-packages (from tensorflow-cpu) (25.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow-cpu)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hungn\miniconda3\lib\site-packages (from tensorflow-cpu) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\hungn\miniconda3\lib\site-packages (from tensorflow-cpu) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hungn\miniconda3\lib\site-packages (from tensorflow-cpu) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow-cpu)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\hungn\miniconda3\lib\site-packages (from tensorflow-cpu) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow-cpu)
#   Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-cpu)
#   Downloading grpcio-1.80.0-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Collecting keras>=3.12.0 (from tensorflow-cpu)
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hungn\miniconda3\lib\site-packages (from tensorflow-cpu) (2.4.3)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow-cpu)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow-cpu)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hungn\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hungn\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hungn\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hungn\miniconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hungn\miniconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-cpu) (0.45.1)
# Requirement already satisfied: rich in c:\users\hungn\miniconda3\lib\site-packages (from keras>=3.12.0->tensorflow-cpu) (14.2.0)
# Collecting namex (from keras>=3.12.0->tensorflow-cpu)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow-cpu)
#   Downloading optree-0.19.0-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hungn\miniconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow-cpu) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hungn\miniconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow-cpu) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hungn\miniconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow-cpu) (0.1.2)
# Downloading tensorflow_cpu-2.21.0-cp313-cp313-win_amd64.whl (351.2 MB)
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/351.2 MB ? eta -:--:--
#    ---------------------------------------- 1.8/351.2 MB 6.9 MB/s eta 0:00:51
#    ---------------------------------------- 2.9/351.2 MB 6.0 MB/s eta 0:00:59
#    ---------------------------------------- 3.4/351.2 MB 5.6 MB/s eta 0:01:02
#    ---------------------------------------- 3.4/351.2 MB 5.6 MB/s eta 0:01:02
#    ---------------------------------------- 3.9/351.2 MB 3.7 MB/s eta 0:01:33
#     --------------------------------------- 7.1/351.2 MB 5.3 MB/s eta 0:01:05
#    - -------------------------------------- 9.2/351.2 MB 6.0 MB/s eta 0:00:57
#    - -------------------------------------- 10.5/351.2 MB 6.1 MB/s eta 0:00:57
#    - -------------------------------------- 11.5/351.2 MB 6.2 MB/s eta 0:00:56
#    - -------------------------------------- 14.2/351.2 MB 6.5 MB/s eta 0:00:52
#    - -------------------------------------- 15.7/351.2 MB 6.7 MB/s eta 0:00:51
#    - -------------------------------------- 17.0/351.2 MB 6.7 MB/s eta 0:00:51
kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, termcolor, protobuf, optree, opt_einsum, ml_dtypes, h5py, grpcio, google_pasta, gast, astunparse, absl-py, keras, tensorflow-cpu
#
#    -- -------------------------------------  1/17 [libclang]
#    -- -------------------------------------  1/17 [libclang]
#    ----------- ----------------------------  5/17 [protobuf]
#    ----------- ----------------------------  5/17 [protobuf]
#    ---------------- -----------------------  7/17 [opt_einsum]
#    --------------------- ------------------  9/17 [h5py]
#    --------------------- ------------------  9/17 [h5py]
#    ----------------------- ---------------- 10/17 [grpcio]
#    ----------------------- ---------------- 10/17 [grpcio]
#    ------------------------- -------------- 11/17 [google_pasta]
#    -------------------------------- ------- 14/17 [absl-py]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ------------------------------------- -- 16/17 [tensorflow-cpu]
#    ---------------------------------------- 17/17 [tensorflow-cpu]
#
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.14.0 libclang-18.1.1 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.1 tensorflow-cpu-2.21.0 termcolor-3.3.0 wrapt-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Chuẩn bị dữ liệu
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Chuyển đổi sang định dạng float32.
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
x_train, x_test = x_train.reshape([-1, num_features]).T, x_test.reshape([-1, num_features]).T
# Chuẩn hóa ảnh từ from [0, 255] to [0, 1].
x_train, x_test = x_train / 255., x_test / 255.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 12s 1us/step

# %%
m = x_train.shape[0]

# %%
def cross_entropy(predictions, targets, epsilon=1e-12):
    """
    Computes cross entropy between targets (encoded as one-hot vectors)
    and predictions. 
    Input: predictions (N, k) ndarray
           targets (N, k) ndarray        
    Returns: scalar
    """
    predictions = np.clip(predictions, epsilon, 1. - epsilon)
    N = predictions.shape[0]
    ce = -np.sum(targets*np.log(predictions+1e-9))/N
    return ce

# %%
def init_params():
    W1 = np.random.rand(n_hidden_1, 784) - 0.5
    b1 = np.random.rand(n_hidden_1, 1) - 0.5
    W2 = np.random.rand(num_classes, n_hidden_1) - 0.5
    b2 = np.random.rand(num_classes, 1) - 0.5
    return W1, b1, W2, b2

def ReLU(Z):
    return np.maximum(Z, 0)

def softmax(Z):
    A = np.exp(Z) / sum(np.exp(Z))
    return A

def cross_entropy(predictions, targets, epsilon=1e-12):
    """
    tính giá trị cross entropy giữa targets và predictions. 
    Input: predictions (N, k)
           targets (N, k)        
    Returns: scalar
    """
    predictions = np.clip(predictions, epsilon, 1. - epsilon)
    N = predictions.shape[0]
    ce = -np.sum(targets*np.log(predictions+1e-9))/N
    return ce
    
def forward_prop(W1, b1, W2, b2, X):
    Z1 = W1.dot(X) + b1
    A1 = ReLU(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = softmax(Z2)
    return Z1, A1, Z2, A2

def ReLU_deriv(Z):
    return Z > 0

def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    one_hot_Y[np.arange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y):
    one_hot_Y = one_hot(Y)
    dZ2 = A2 - one_hot_Y
    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2)
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)
    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1)
    return dW1, db1, dW2, db2

def update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1    
    W2 = W2 - alpha * dW2  
    b2 = b2 - alpha * db2    
    return W1, b1, W2, b2

# %%
losses = []
def get_predictions(A2):
    return np.argmax(A2, 0)

def get_accuracy(predictions, Y):
    # print(predictions, Y)
    return np.sum(predictions == Y) / Y.size

def gradient_descent(X, Y, alpha, iterations):
    W1, b1, W2, b2 = init_params()
    for i in range(iterations):
        Z1, A1, Z2, A2 = forward_prop(W1, b1, W2, b2, X)
        dW1, db1, dW2, db2 = backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y)
        W1, b1, W2, b2 = update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha)
        predictions = get_predictions(A2)
        losses.append(cross_entropy(predictions, Y))
        if i % 10 == 9:
            # print("Iteration: ", i+1)
            # predictions = get_predictions(A2)
            # print('Accuracy: %.3f' %(get_accuracy(predictions, Y)))
            print('Iteration: %d, accuracy: %.3f' %(i + 1, get_accuracy(predictions, Y)))
    return W1, b1, W2, b2

# %%
alpha = 0.01
n_epoch = 100
W1, b1, W2, b2 = gradient_descent(x_train, y_train, alpha, n_epoch)
# Out:
# Iteration: 10, accuracy: 0.269
# Iteration: 20, accuracy: 0.491
# Iteration: 30, accuracy: 0.678
# Iteration: 40, accuracy: 0.775
# Iteration: 50, accuracy: 0.727
# Iteration: 60, accuracy: 0.831
# Iteration: 70, accuracy: 0.820
# Iteration: 80, accuracy: 0.862
# Iteration: 90, accuracy: 0.863
# Iteration: 100, accuracy: 0.861

# %%
# Biểu đồ biểu diễn độ biến thiên của hàm mất mát qua các vòng lặp
plt.plot([i for i in range(len(losses))], losses, label='Loss line')
# plt.plot(X, np.array(W * X + b), label='Fitted line')
plt.legend()
plt.show()
