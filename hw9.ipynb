# %% [markdown]
# # Neural Network Example
#
# Xây dựng neural network với hai tầng ẩn (hidden layer). Các trọng số và mối liên hệ giữa các tầng ẩn được thiết lập và cài đặt bằng việc sử dụng API của thư viện PyTorch

# %% [markdown]
# ## Neural Network Overview
#
# <img src="http://cs231n.github.io/assets/nn1/neural_net2.jpeg" alt="nn" style="width: 400px;"/>
#
# ## MNIST Dataset Overview

# %%
pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.28.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hungn\miniconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\hungn\miniconda3\lib\site-packages (from torch) (80.9.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hungn\miniconda3\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\hungn\miniconda3\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\hungn\miniconda3\lib\site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\hungn\miniconda3\lib\site-packages (from torchvision) (12.1.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hungn\miniconda3\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/114.6 MB ? eta -:--:--
#     --------------------------------------- 1.8/114.6 MB 6.8 MB/s eta 0:00:17
#    - -------------------------------------- 4.2/114.6 MB 9.3 MB/s eta 0:00:12
#    -- ------------------------------------- 6.8/114.6 MB 10.2 MB/s eta 0:00:11
#    --- ------------------------------------ 9.2/114.6 MB 10.6 MB/s eta 0:00:10
#    ---- ----------------------------------- 11.8/114.6 MB 10.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 13.9/114.6 MB 10.8 MB/s eta 0:00:10
#    ----- ---------------------------------- 16.5/114.6 MB 11.1 MB/s eta 0:00:09
#    ------ --------------------------------- 18.9/114.6 MB 11.2 MB/s eta 0:00:09
#    ------ --------------------------------- 18.9/114.6 MB 11.2 MB/s eta 0:00:09
#    -------- ------------------------------- 23.6/114.6 MB 11.1 MB/s eta 0:00:09
#    --------- ------------------------------ 26.0/114.6 MB 11.1 MB/s eta 0:00:08
#    --------- ------------------------------ 28.6/114.6 MB 11.2 MB/s eta 0:00:08
#    ---------- ----------------------------- 30.4/114.6 MB 11.0 MB/s eta 0:00:08
#    ----------- ---------------------------- 33.6/114.6 MB 11.3 MB/s eta 0:00:08
#    ------------ --------------------------- 35.4/114.6 MB 11.1 MB/s eta 0:00:08
#    ------------ --------------------------- 37.2/114.6 MB 10.9 MB/s eta 0:00:08
#    ------------- -------------------------- 37.5/114.6 MB 10.4 MB/s eta 0:00:08
#    ------------- -------------------------- 37.5/114.6 MB 10.4 MB/s eta 0:00:08
#    ------------- -------------------------- 37.7/114.6 MB 9.4 MB/s eta 0:00:09
#    ------------- -------------------------- 37.7/114.6 MB 9.4 MB/s eta 0:00:09
#    ------------- -------------------------- 38.0/114.6 MB 8.8 MB/s eta 0:00:09
#    ------------- -------------------------- 38.0/114.6 MB 8.8 MB/s eta 0:00:09
#    ------------- -------------------------- 38.0/114.6 MB 8.8 MB/s eta 0:00:09
#    ------------- -------------------------- 38.0/114.6 MB 8.8 MB/s eta 0:00:09
#    ------------- -------------------------- 38.8/114.6 MB 7.3 MB/s eta 0:00:11
#    ------------- -------------------------- 39.3/114.6 MB 7.2 MB/s eta 0:00:11
#    ------------- -------------------------- 39.3/114.6 MB 7.2 MB/s eta 0:00:11
#    ------------- -------------------------- 39.6/114.6 MB 6.8 MB/s eta 0:00:12
#    ------------- -------------------------- 39.6/114.6 MB 6.8 MB/s eta 0:00:12
#    ------------- -------------------------- 39.6/114.6 MB 6.8 MB/s eta 0:00:12
#    ------------- -------------------------- 39.6/114.6 MB 6.8 MB/s eta 0:00:12
#    ------------- -------------------------- 39.6/114.6 MB 6.8 MB/s eta 0:00:12
#    ------------- -------------------------- 39.6/114.6 MB 6.8 MB/s eta 0:00:12
#    ------------- -------------------------- 39.8/114.6 MB 5.6 MB/s eta 0:00:14
#    -------------- ------------------------- 40.1/114.6 MB 5.4 MB/s eta 0:00:14
#    -------------- ------------------------- 42.5/114.6 MB 5.6 MB/s eta 0:00:13
#    --------------- ------------------------ 44.3/114.6 MB 5.7 MB/s eta 0:00:13
#    ---------------- ----------------------- 46.4/114.6 MB 5.8 MB/s eta 0:00:12
#    ----------------- ---------------------- 48.8/114.6 MB 5.9 MB/s eta 0:00:12
#    ----------------- ---------------------- 50.9/114.6 MB 6.0 MB/s eta 0:00:11
#    ------------------ --------------------- 53.2/114.6 MB 6.1 MB/s eta 0:00:10
#    ------------------- -------------------- 55.6/114.6 MB 6.3 MB/s eta 0:00:10
#    -------------------- ------------------- 57.9/114.6 MB 6.4 MB/s eta 0:00:09
#    -------------------- ------------------- 59.8/114.6 MB 6.4 MB/s eta 0:00:09
#    --------------------- ------------------ 61.6/114.6 MB 6.5 MB/s eta 0:00:09
#    ---------------------- ----------------- 63.7/114.6 MB 6.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 65.8/114.6 MB 6.7 MB/s eta 0:00:08
#    ----------------------- ---------------- 68.2/114.6 MB 6.7 MB/s eta 0:00:07
#    ------------------------ --------------- 70.5/114.6 MB 6.8 MB/s eta 0:00:07
#    ------------------------- -------------- 72.6/114.6 MB 6.9 MB/s eta 0:00:07
#    -------------------------- ------------- 75.2/114.6 MB 7.0 MB/s eta 0:00:06
#    --------------------------- ------------ 77.3/114.6 MB 7.1 MB/s eta 0:00:06
#    --------------------------- ------------ 79.7/114.6 MB 7.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 82.1/114.6 MB 7.2 MB/s eta 0:00:05
#    ----------------------------- ---------- 84.7/114.6 MB 7.3 MB/s eta 0:00:05
#    ------------------------------ --------- 87.3/114.6 MB 7.4 MB/s eta 0:00:04
#    ------------------------------- -------- 89.4/114.6 MB 7.5 MB/s eta 0:00:04
#    -------------------------------- ------- 92.0/114.6 MB 7.5 MB/s eta 0:00:03
#    -------------------------------- ------- 94.4/114.6 MB 7.6 MB/s eta 0:00:03
#    --------------------------------- ------ 96.7/114.6 MB 7.7 MB/s eta 0:00:03
#    ---------------------------------- ----- 98.6/114.6 MB 7.7 MB/s eta 0:00:03
#    ----------------------------------- ---- 100.7/114.6 MB 7.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 103.0/114.6 MB 7.8 MB/s eta 0:00:02
#    ------------------------------------ --- 105.6/114.6 MB 7.8 MB/s eta 0:00:02
#    ------------------------------------- -- 107.7/114.6 MB 7.9 MB/s eta 0:00:01
#    -------------------------------------- - 110.4/114.6 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  112.7/114.6 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  114.3/114.6 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 MB 7.9 MB/s  0:00:14
# Downloading torchvision-0.26.0-cp313-cp313-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ------------------- -------------------- 2.1/4.3 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 10.5 MB/s  0:00:00
# Downloading torchaudio-2.11.0-cp313-cp313-win_amd64.whl (328 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------- -------------------------- 2.1/6.3 MB 10.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.3 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 5.8/6.3 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 9.3 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 9.5 MB/s  0:00:00
# Downloading filelock-3.28.0-py3-none-any.whl (39 kB)
# Installing collected packages: torchaudio, mpmath, sympy, fsspec, filelock, torch, torchvision
#
#    ---------------------------------------- 0/7 [torchaudio]
#    ---------------------------------------- 0/7 [torchaudio]
#    ----- ---------------------------------- 1/7 [mpmath]
#    ----- ---------------------------------- 1/7 [mpmath]
#    ----- ---------------------------------- 1/7 [mpmath]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------- ---------------------------- 2/7 [sympy]
#    ----------------- ---------------------- 3/7 [fsspec]
#    ----------------- ---------------------- 3/7 [fsspec]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------------- 7/7 [torchvision]
#
# Successfully installed filelock-3.28.0 fsspec-2026.3.0 mpmath-1.3.0 sympy-1.14.0 torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import absolute_import, division, print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
import numpy as np

# %%
# Chuẩn bị dữ liệu
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Chuyển đổi sang định dạng float32.
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)
# Chuẩn hóa ảnh từ from [0, 255] to [0, 1].
x_train, x_test = x_train / 255, x_test / 255
x_train, x_test, y_train, y_test = torch.from_numpy(x_train), torch.from_numpy(x_test), torch.from_numpy(y_train).type(torch.LongTensor), torch.from_numpy(y_test).type(torch.LongTensor)

# %%
# MNIST dataset parameters.
num_classes = 10 # total classes (0-9 digits).
num_features = 784 # data features (img shape: 28*28).

# Network parameters.
n_hidden_1 = 128 # 1st layer number of neurons.
# n_hidden_2 = 256 # 2nd layer number of neurons.

# %%
batch_size = 16

# %%
trainloader = []
for (i,j) in zip(x_train, y_train):
    trainloader.append([i,j])
trainloader = torch.utils.data.DataLoader(trainloader, shuffle=True, batch_size=batch_size)

testloader = []
for (i,j) in zip(x_test, y_test):
    testloader.append([i,j])
testloader = torch.utils.data.DataLoader(testloader, shuffle=True, batch_size=None)

# %% [markdown]
# ## Hiển thị một vài ví dụ

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
dataiter = iter(trainloader)
images, labels = dataiter.__next__()
images = images.numpy()

# hiển thị dữ liệu theo từng batch và nhãn tương ứng
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(batch_size):
    ax = fig.add_subplot(2, int(batch_size/2), idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

# %%
import torch.nn as nn
import torch.nn.functional as F

## định nghĩa mạng
class MLPModel(nn.Module):
    def __init__(self):
        super(MLPModel, self).__init__()
        self.fc1 = nn.Linear(num_features, n_hidden_1)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(n_hidden_1, num_classes)

    def forward(self, x):
        # chuyển từ định dạng ma trận thành vector
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return x

# initialize the NN
model = MLPModel()
print(model)
# Out:
# MLPModel(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
import torch.optim as optim
# trong hàm loss cross entropy đã áp dụng hàm soft max cho vector đầu ra
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
def accuracy():
    correct = 0
    total = 0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            # calculate outputs by running images through the network
            outputs = model(images)
            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct/total

# %%
losses = []
for epoch in range(100):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
    losses.append(running_loss)
    if epoch % 10 == 9:
        print('Iteration: %d, accuracy: %.3f' %(epoch + 1, accuracy()))

print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 22
#      20     losses.append(running_loss)
#      21     if epoch % 10 == 9:
# ---> 22         print('Iteration: %d, accuracy: %.3f' %(epoch + 1, accuracy()))
#      24 print('Finished Training')
#
# Cell In[21], line 12, in accuracy()
#      10         # the class with the highest energy is what we choose as prediction
#      11         _, predicted = torch.max(outputs.data, 1)
# ---> 12         total += labels.size(0)
#      13         correct += (predicted == labels).sum().item()
#      15 return correct/total
#
# IndexError: Dimension specified as 0 but tensor has no dimensions

# %%
# Biểu đồ biểu diễn độ biến thiên của hàm mất mát qua các vòng lặp
plt.plot([i for i in range(len(losses))], losses, label='Loss line')
# plt.plot(X, np.array(W * X + b), label='Fitted line')
plt.legend()
plt.show()

# %% [markdown]
# ## Bài tập
#
# *   Tiến hành huấn luyện mô hình với số lượng epoch lần lượt là 50, 100, 150.Rút ra nhận xét.

# %% [markdown]
# *   Hiển thị một số kết quả

# %%
# obtain one batch of test images
dataiter = iter(testloader)
images, labels = dataiter.next()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(batch_size):
    ax = fig.add_subplot(2, batch_size/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))

# %% [markdown]
# ## Bài tập
#
# *   Thiết lập thêm 3 mạng nơ ron với số tầng ẩn lần lượt là 3,5 (số lượng nơ ron của các tầng tùy ý). Với mỗi mạng mới được sinh ra, áp dụng learning-rate lần lượt bằng 0.1, 0,05, 0.001 để huấn luyện. Huấn luyện qua khoảng 100 epoch.
# *   Chia tập train hiện có thành 2 phần. **85%** dữ liệu làm tập **train**, **15%** còn lại làm tập **dev**. Huấn luyện các mô hình tạo ra ở bước trên với tập **train** mới, sau đó kiểm thử trên tập **dev**.
# * Dùng các model kiểm thử trên tập **test**. So sánh model cho kết quả tốt nhất khi kiểm thử trên 2 tập này và rút ra nhận xét về vai trò của tập **dev**
